# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)

# %%
import requests as req
from bs4 import BeautifulSoup

# %%
url = "https://www.hindustantimes.com/"

# %%
r = req.get(url)
print(r.status_code)
# Out:
# 401

# %%
import requests as req
from bs4 import BeautifulSoup

# URL of the website to scrape
url = "https://www.hindustantimes.com/"

# Headers to mimic a browser request
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Referer": "https://www.google.com"
}

# Make the GET request with headers
r = req.get(url, headers=headers)

# Check the status code
if r.status_code == 200:
    print("Request successful!")

    # Parse the HTML content
    soup = BeautifulSoup(r.text, 'html.parser')

    # Extract and print the title of the webpage
    print("Page Title:", soup.title.text)

    # Example: Extract and print all article headlines
    headlines = soup.find_all('h2')
    print("\nHeadlines:")
    for headline in headlines:
        print(headline.text.strip())
else:
    print(f"Request failed with status code: {r.status_code}")
# Out:
# Request successful!
# Page Title: US News: Stay Updated with the Latest US News on Politics, Crime, and Local Stories of today| Hindustan Times | Hindustan Times
#
# Headlines:
# ‘Every inch of Pak within BrahMos range': Rajnath Singh's big warning
# What is asbestos, cancer-causing mineral at centre of lawsuits against J&J?
# ‘Kabul is India’s proxy’: Pakistan's Khawaja Asif asks Afghans to return home
# How South Korean author Baek Se-hee, 35, gave new life to 5 people before dying
# How this doctor's 8-year fight forced FSSAI to drop ‘ORS’ tag from energy drinks
# Trending
# World News
# India News
# Entertainment
# Lifestyle
# Cricket
# Astrology
# Photos
# Videos
