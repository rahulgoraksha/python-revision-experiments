# %% [markdown]
# ## Feature and Label in Machine learning
#
# - Feature: property of your training data
# - Label: output you get from your model after training the data

# %% [markdown]
# ![image.png](attachment:image.png)
