# %% [markdown]
# - Precision: मॉडेलने Positive सांगितलेल्यांपैकी खरे Positive किती आहेत.
# - Recall: प्रत्यक्ष Positive पैकी मॉडेलने ओळखलेले Positive किती आहेत.
# - F1 Score: Precision आणि Recall यांचा संतुलित सरासरी माप.
# - Support: प्रत्येक वर्गासाठी डेटामधील खऱ्या नमुन्यांची संख्या.
