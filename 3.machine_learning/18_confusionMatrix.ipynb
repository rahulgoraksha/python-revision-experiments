# %% [markdown]
# ### Confusion Matrix:
#
# - A confusion matrix is an N*N matrix used for evaluating the performance of classification model, where N is the number fo the target classes.
# - This comapres teh actual target v/s predicted target values
#
# ![cm](https://images.prismic.io/turing/65a53ce07a5e8b1120d58880_image7_11zon_aca1dd9e4a.webp?auto=format,compress)
# ![example](https://plat.ai/wp-content/uploads/Table1-2.png.webp)
#
# ![img10.jpeg](attachment:img10.jpeg)
# ![img11.jpeg](attachment:img11.jpeg)
