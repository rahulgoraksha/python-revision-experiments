# %% [markdown]
# ### Support Vector Machine
#
# - It is supervised machine learning
# - It support both regression & classification as well, but mostly is used for classification kind of the task
#
# ![img9.jpeg](attachment:img9.jpeg)
