# %% [markdown]
# ### Ensemble Learning
#
# - to classificaton or prediction so we train multiple train model to get the average output
#
# ### technique approach in ensemble learning
# 1. Bagging
# 2. Boosting

# %% [markdown]
# - random with replacement. -->
# 1. sample replacement is called bootstrap
# 2. model train kay bath result aggregated is called aggregation

# %% [markdown]
# **data set as well as feature are sampled**

# %% [markdown]
# 1. Bagging : uderlying model can be anything (SVM, knn, logistic regression, etc)
# 2. Bagged trees : each model is tree

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv"
df = pd.read_csv(url)

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
df.Outcome.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/l0/yk46hdzn3tgb8l9p047d0bkm0000gn/T/ipykernel_1837/2749068430.py in ?()
# ----> 1 df.Outcome.value_count()
#
# ~/Downloads/python-revision-experiments/.venv/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value_count'
