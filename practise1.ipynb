# %% [markdown]
# 09-01-2026

# %%
#printing a message to indicate the start of Python scripting practice
print("This marks the beginning of my Python scripting practice once again—revisiting core concepts and strengthening fundamentals as part of my focused preparation and revision journey for 2026. 🚀")
# Out:
# This marks the beginning of my Python scripting practice once again—revisiting core concepts and strengthening fundamentals as part of my focused preparation and revision journey for 2026. 🚀

# %%
# used to comment out the previous line

# %%
#added comment using "ctrl + ?"

# rahul is the best boy

# %% [markdown]
# 10-01-2026

# %%
#variable assignment
a = 5
print(a)
# Out:
# 5

# %%
Instructor = "Rahul Goraksha" # assigning the instructor's name to a variable

print("Python by", Instructor, sep=" - ") # printing the instructor's name stored in the variable
# Out:
# Python by - Rahul Goraksha

# %%
print(5 + 3) # simple addition operation to demonstrate basic arithmetic
# Out:
# 8

# %%
print("5 + 3") # printing the string "5+3" to show difference between string and arithmetic operation
# Out:
# 5 + 3

# %%
#putting arithmetic operations with variables
b = 10

c = 20

print(b+c) # printing the sum of two variables b and c
print("The sum of", b, "and", c, "is", b + c) # printing a descriptive message along with the sum of b and c

print(c/b) # printing the result of division of c by b
print("The division of", c, "by", b, "gives", c / b) # printing a descriptive message along with the result of division

print(c*b) # printing the result of multiplication of c and b
print("The multiplication of", c, "and", b, "results in", c * b) # printing a descriptive message along with the result of multiplication

print(c-b) # printing the result of subtraction of b from c
print("The subtraction of", b, "from", c, "yields", c - b) # printing a descriptive message along with the result of subtraction
# Out:
# 30
# The sum of 10 and 20 is 30
# 2.0
# The division of 20 by 10 gives 2.0
# 200
# The multiplication of 20 and 10 results in 200
# 10
# The subtraction of 10 from 20 yields 10

# %% [markdown]
# # Key Understanding About Python
#
# ## Python Code Execution Steps
#
# 1. **Lexical Analysis**
#    The Python interpreter breaks the source code into smaller parts called **tokens**, such as keywords, identifiers, numbers, symbols, and punctuation.
#
# 2. **Syntax Parsing**
#    Python checks whether the structure of the code is correct. If the syntax rules are violated, a **SyntaxError** is raised.
#
# 3. **Bytecode Generation**
#    After successful syntax checking, the code is converted into a simpler set of instructions called **bytecode**.
#
# 4. **Execution by PVM**
#    The **Python Virtual Machine (PVM)** executes the bytecode and performs operations like calculations, value assignments, and function calls.
#
# 5. **Error Handling and Output**
#    During execution, Python handles runtime errors if any occur and displays the output such as printed messages or returned values.

# %% [markdown]
# ## Interpretor
# 1. It tends to translate and execute code line by line.
# 2. Execution: Line by line
# 3. Speed: Slower
# 4. Debugging: Easier
# 5. Example: Python, JavaScript, Ruby and PHP
#
# # Compiler
# 1. It tends to translate the entire code into machine code before program runs
# 2. Execution: Entire program at once
# 3. Speed: Faster
# 4. Debugging: Complex
# 5. Example: C, C++, Java

# %% [markdown]
# - Variable: It is the symbolic name that is a reference or pointer to an object, they are like a container that can fill in wit the different with different types of datatypes such as String, Int, Float, Boolean, list tuple, range, disctionary, set
# - It's name should be started with letter or _
# - It's name can contain letter, numbers, underscore (_)
# - Variables are case sensitive
# - Variables names can't be reserved word like function, keywords, loops, etc.

# %%
# variable name = value
greeting = "Hello World!"
print(greeting)
# Out:
# Hello World!

# %%
a = 1  # integer assignment
print(a)

b = 1.1375 # float assignment
print(b)

c = "Rahul Goraksha" # string assignment
print(c)

x = 10 # adding 10 to the variable x and printing the result
print(x+10) 

p, q, r = 11,12,13 # printing multiple variables p, q, and r
print(p, q,r) 



# Demonstrating variable reassignment
MyName  = "Rahul Goraksha"  #Pascal Case
myName = "Rahul Goraksha"   #camel Case
myname = "Rahul Goraksha"   #flat Case
my_name = "Rahul Goraksha"  #snake Case
# Out:
# 1
# 1.1375
# Rahul Goraksha
# 20
# 11 12 13

# %%
b = 1.1
print(b)
# Out:
# 1.1

# %% [markdown]
# # Data Type
#
# 1. To understand the type of *datatype* use of **type()**
#
# - **String**
# - **Integer**
# - **Numeric:** : Integer, Float,  Complex
# - **Sequence** : String, List, Tuple
# - **Dictionary**
# - **Set**
# - **Boolean**
# - **Binary** : Bytes, Bytearray, Memoryview

# %%
a = 1
b = 1

print(a+b)

print(type(b)) #checking the type of variable b


c = "1"
d = "1"
print(c+d) 

print(type(c)) #checking the type of variable c
# Out:
# 2
# <class 'int'>
# 11
# <class 'str'>

# %% [markdown]
# **Assignment -1**

# %%
print("Python is Fun.") #printing a message about Python being fun

print('''"Quotes" and 'simgle quotes' can be tricky.''') #printing a message about quotes in Python
# Out:
# Python is Fun.
# "Quotes" and 'simgle quotes' can be tricky.

# %%
name = "Rahul Goraksha" #assigning name to a variable
age = 21               #assigning age to a variable
city = "Chicago"      #assigning city to a variable

print("My name is", name + ".", "I am", age, "years old and I live in", city + ".") #printing a message with the variables inserted

print(f"My name is {name}. I am {age} years old and I live in {city}.") #printing a formatted message with the variables inserted
# Out:
# My name is Rahul Goraksha. I am 21 years old and I live in Chicago.
# My name is Rahul Goraksha. I am 21 years old and I live in Chicago.
